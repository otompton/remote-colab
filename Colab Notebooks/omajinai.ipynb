# %% [markdown]
# ## おまじない

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://otompton:n90hcLmi@github.com/otompton/kaggle.git "./"
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
cd My\ Drive
# Out:
# /content/drive/My Drive

# %%
# !tree -d
# Out:
# /bin/bash: tree: command not found

# %%
# !apt-get install tree
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 40.7 kB of archives.
# After this operation, 105 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tree amd64 1.7.0-5 [40.7 kB]
# Fetched 40.7 kB in 0s (1,050 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 135004 files and directories currently installed.)
# Preparing to unpack .../tree_1.7.0-5_amd64.deb ...
# Unpacking tree (1.7.0-5) ...
# Setting up tree (1.7.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# !tree -d
# Out:
# .
# ├── github
# │   ├── Colab Notebooks
# │   ├── datasets
# │   │   ├── kaggle
# │   │   │   └── titanic
# │   │   └── ml100knock
# │   │       ├── 10_Questionnaire_analysis
# │   │       ├── 1_web_order
# │   │       ├── 2_Retail_data
# │   │       ├── 3_Customer_information
# │   │       ├── 4_ Customer_behavior
# │   │       ├── 5_Customer_withdrawal
# │   │       ├── 6_Logistics_route
# │   │       ├── 7_ Logistics_network
# │   │       ├── 8_ Numerical_simulation
# │   │       └── 9_Potential_customer
# │   │           ├── img
# │   │           └── mov
# │   └── setting
# └── private
#
# 20 directories

# %%
ls -a
# Out:
# github/  private/

# %%
cat .gitignore
# Out:
# cat: .gitignore: No such file or directory

# %%
# !ls -a .*
# Out:
# ls: cannot access '.*': No such file or directory

# %%
cd github
# Out:
# /content/drive/My Drive/github

# %%
ls -a
# Out:
# 'Colab Notebooks'/   datasets/   .git/   .gitignore   README.md   setting/

# %%
cat .gitignore
# Out:
# /datasets/*
# /setting/*

# %%
# !git add -A

# %%
# !git commit -m 'add .gitignore'
# Out:
# [master c9f37e0] add .gitignore
#  4 files changed, 4 insertions(+), 131 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 Colab Notebooks/README.ipynb
#  rewrite Colab Notebooks/omajinai.ipynb (98%)
#  delete mode 100644 Colab Notebooks/setting.ipynb

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 7.55 KiB | 1.51 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/otompton/Kaggle.git
# To https://github.com/otompton/kaggle.git
#    0a8db4f..c9f37e0  master -> master

# %%
ls
# Out:
# 'Colab Notebooks'/   datasets/   README.md   setting/

# %%
ls
# Out:
# 'Colab Notebooks'/   datasets/   README.md   setting/

# %%
ls datasets/ml100knock/
# Out:
#  10_Questionnaire_analysis/   6_Logistics_route/
#  1_web_order/                '7_ Logistics_network'/
#  2_Retail_data/              '8_ Numerical_simulation'/
#  3_Customer_information/      9_Potential_customer/
# '4_ Customer_behavior'/       readme.txt
#  5_Customer_withdrawal/

# %%
# !git rm -r --cached setting/*
# Out:
# rm 'setting/kaggle.json'

# %%
ls
# Out:
# 'Colab Notebooks'/   datasets/   README.md   setting/

# %%
cd ../
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# github/  private/

# %%
# !git clone https://github.com/otompton/data_analysis-colab.git
# Out:
# Cloning into 'data_analysis-colab'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 122 (delta 6), reused 21 (delta 4), pack-reused 99
# Receiving objects: 100% (122/122), 162.98 MiB | 22.32 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
ls
# Out:
# data_analysis-colab/  github/  private/

# %%
cd data_analysis-colab/
# Out:
# /content/drive/My Drive/data_analysis-colab

# %%
ls
# Out:
# 'Colab Notebooks'/   README.md

# %%
rm -rf *

# %%
ls
# Out:
# data_analysis-colab/  github/  private/

# %%
rm -rf data_analysis-colab/

# %%
# !git clone https://github.com/otompton/data_analysis-colab.git
# Out:
# Cloning into 'data_analysis-colab'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 122 (delta 6), reused 21 (delta 4), pack-reused 99
# Receiving objects: 100% (122/122), 162.98 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# !tree -d
# Out:
# .
# ├── data_analysis-colab
# │   ├── Colab Notebooks
# │   ├── kaggle
# │   │   └── titanic
# │   ├── ml100knock
# │   │   ├── 10_Questionnaire_analysis
# │   │   ├── 1_web_order
# │   │   ├── 2_Retail_data
# │   │   ├── 3_Customer_information
# │   │   ├── 4_ Customer_behavior
# │   │   ├── 5_Customer_withdrawal
# │   │   ├── 6_Logistics_route
# │   │   ├── 7_ Logistics_network
# │   │   ├── 8_ Numerical_simulation
# │   │   └── 9_Potential_customer
# │   │       ├── img
# │   │       └── mov
# │   └── setting
# ├── github
# │   ├── Colab Notebooks
# │   ├── datasets
# │   │   ├── kaggle
# │   │   │   └── titanic
# │   │   └── ml100knock
# │   │       ├── 10_Questionnaire_analysis
# │   │       ├── 1_web_order
# │   │       ├── 2_Retail_data
# │   │       ├── 3_Customer_information
# │   │       ├── 4_ Customer_behavior
# │   │       ├── 5_Customer_withdrawal
# │   │       ├── 6_Logistics_route
# │   │       ├── 7_ Logistics_network
# │   │       ├── 8_ Numerical_simulation
# ...

# %%
cp -r github/setting/* data_analysis-colab/

# %%
# !mkdir data_analysis-colab//setting

# %%
mv data_analysis-colab/kaggle.json data_analysis-colab/setting/

# %%
ls
# Out:
# data_analysis-colab/  github/  private/

# %%
ls
# Out:
# data_analysis-colab/  github/  private/

# %%
cd data_analysis-colab/
# Out:
# /content/drive/My Drive/data_analysis-colab

# %%
# !git add -A
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/data_analysis-colab/.git/

# %%
pwd
# Out:
# '/content/drive/My Drive/data_analysis-colab'

# %%
ls
# Out:
# 'Colab Notebooks'/   kaggle/   ml100knock/   README.md   setting/

# %%
cd ../
# Out:
# /content/drive/My Drive

# %%
ls
# Out:
# data_analysis-colab/  github/  private/

# %%
# !git clone https://github.com/otompton/remote-colab.git
# Out:
# Cloning into 'remote-colab'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
ls
# Out:
# data_analysis-colab/  github/  private/  remote-colab/

# %%
cd remote-colab/
# Out:
# /content/drive/My Drive/remote-colab

# %%
# !git add -A

# %%
# !git commit -m 'initial commit'
# Out:
# [master 3be6b6b] initial commit
#  5 files changed, 6 insertions(+)
#  create mode 100644 Colab Notebooks/20191228test.ipynb
#  create mode 100644 Colab Notebooks/omajinai.ipynb
#  create mode 100644 Colab Notebooks/setting.ipynb
#  create mode 100644 datasets/.gitignore
#  create mode 100644 setting/kaggle.json

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
ls
# Out:
# 'Colab Notebooks'/   datasets/   README.md   setting/

# %%
pwd
# Out:
# '/content/drive/My Drive/remote-colab'
